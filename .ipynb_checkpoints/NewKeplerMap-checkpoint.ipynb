# %%
# import libraries

import pandas as pd
import os
from keplergl import KeplerGl
from pyproj import CRS
import numpy as np
from matplotlib import pyplot as plt

# %%
#set path
path = r'C:\Users\nrsmi\Documents\CareerFoundry\New_York_CitiBike_Analysis\Data\Prepared_Data'

# %%
# import df
df = pd.read_csv(os.path.join(path, 'reduced_data_to_plot_7.csv'), index_col = 0 )

# %%
df.head()
# Out:
#                    start_station_name          end_station_name  start_lat  \
# date
# 2022-01-01   Cleveland Pl & Spring St       Mott St & Prince St  40.722104
# 2022-01-01         Broadway & E 14 St           E 25 St & 1 Ave  40.734546
# 2022-01-01             28 Ave & 35 St       Vernon Blvd & 30 Rd  40.767100
# 2022-01-01       Bergen St & Smith St  Atlantic Ave & Furman St  40.686744
# 2022-01-01  Schermerhorn St & Bond St           Smith St & 3 St  40.688417
#
#             start_lng    end_lat    end_lng  avgTemp  bike_rides_daily  \
# date
# 2022-01-01 -73.997249  40.723180 -73.994800     11.6             20428
# 2022-01-01 -73.990741  40.738177 -73.977387     11.6             20428
# 2022-01-01 -73.916986  40.770845 -73.934171     11.6             20428
# 2022-01-01 -73.990632  40.691652 -73.999979     11.6             20428
# 2022-01-01 -73.984517  40.678724 -73.995991     11.6             20428
#
#             ride_duration
# date
# 2022-01-01      25.322883
# 2022-01-01      10.860767
# 2022-01-01       9.277000
# 2022-01-01       3.747900
# 2022-01-01       5.517417

# %%
# Create a value column and group by start and end station 

df['value'] = 1
df_group = df.groupby(['start_station_name', 'end_station_name'])['value'].count().reset_index()

# %%
df_group.head()
# Out:
#   start_station_name  end_station_name  value
# 0   1 Ave & E 110 St  1 Ave & E 110 St     72
# 1   1 Ave & E 110 St   1 Ave & E 39 St      1
# 2   1 Ave & E 110 St   1 Ave & E 62 St      3
# 3   1 Ave & E 110 St   1 Ave & E 68 St      2
# 4   1 Ave & E 110 St   1 Ave & E 78 St      3

# %%
df_group.shape
# Out:
# (430962, 3)

# %%
# Create a new DataFrame with the necessary columns
df_stations = df[['start_station_name', 'end_station_name', 'start_lat', 'start_lng', 'end_lat', 'end_lng']]

# %%
# Merge the station df with the grouped df
df_stations = pd.merge(
    df_stations,
    df_group.rename(columns={'value': 'trips'}),
    on=['start_station_name', 'end_station_name'],
    how='left'  # Use 'left' to ensure all rows from df_stations are retained
)

# %%
df_stations.head()
# Out:
#           start_station_name          end_station_name  start_lat  start_lng  \
# 0   Cleveland Pl & Spring St       Mott St & Prince St  40.722104 -73.997249
# 1         Broadway & E 14 St           E 25 St & 1 Ave  40.734546 -73.990741
# 2             28 Ave & 35 St       Vernon Blvd & 30 Rd  40.767100 -73.916986
# 3       Bergen St & Smith St  Atlantic Ave & Furman St  40.686744 -73.990632
# 4  Schermerhorn St & Bond St           Smith St & 3 St  40.688417 -73.984517
#
#      end_lat    end_lng  trips
# 0  40.723180 -73.994800     28
# 1  40.738177 -73.977387     31
# 2  40.770845 -73.934171      1
# 3  40.691652 -73.999979     48
# 4  40.678724 -73.995991     11

# %%
df_stations.shape
# Out:
# (2379383, 7)

# %%
df_stations_dupes = df_stations[df_stations.duplicated(subset=['start_station_name', 'end_station_name', 'trips'])]

# %%
df_stations_dupes
# Out:
#                 start_station_name          end_station_name  start_lat  \
# 36          West End Ave & W 94 St    Riverside Dr & W 91 St  40.794165
# 49              Broadway & E 14 St           E 25 St & 1 Ave  40.734546
# 88                 1 Ave & E 39 St           E 39 St & 2 Ave  40.747140
# 91                 2 Ave & E 31 St  Cleveland Pl & Spring St  40.742909
# 105               Union St & 4 Ave              4 Ave & 9 St  40.677274
# ...                            ...                       ...        ...
# 2379378  Cathedral Pkwy & Broadway           W 20 St & 8 Ave  40.804283
# 2379379         Park Cir & East Dr              6 Ave & 9 St  40.651531
# 2379380       Division St & Bowery         Sands St & Jay St  40.714193
# 2379381  MacDonough St & Marcy Ave   Centre St & Chambers St  40.680808
# 2379382        White St & Moore St   Bleecker St & Crosby St  40.704508
#
#          start_lng    end_lat    end_lng  trips
# 36      -73.974124  40.793135 -73.977004     34
# 49      -73.990741  40.738177 -73.977387     31
# 88      -73.971130  40.748033 -73.973828     68
# 91      -73.977061  40.722104 -73.997249     19
# 105     -73.982820  40.670513 -73.988766     21
# ...            ...        ...        ...    ...
# 2379378 -73.967036  40.743453 -74.000040      2
# 2379379 -73.972160  40.668127 -73.983776     16
# 2379380 -73.996732  40.700119 -73.986200     14
# 2379381 -73.946169  40.712733 -74.004607      2
# 2379382 -73.935100  40.726156 -73.995102      2
#
# [1948421 rows x 7 columns]

# %%
df_stations_cleaned = df_stations.drop_duplicates(subset=['start_station_name', 'end_station_name', 'trips'])

# %%
df_stations_cleaned.shape
# Out:
# (430962, 7)

# %%
#df_stations_cleaned.to_csv(os.path.join(path, 'reduced_data_StationsTrips.csv'))

# %%
df_stations_cleaned = df_stations_cleaned.sort_values(by='trips', ascending=False)
df_stations_cleaned.head(100)
# Out:
#                       start_station_name                   end_station_name  \
# 4625              Central Park S & 6 Ave             Central Park S & 6 Ave
# 3590          7 Ave & Central Park South         7 Ave & Central Park South
# 4289            Roosevelt Island Tramway           Roosevelt Island Tramway
# 7081   Grand Army Plaza & Central Park S  Grand Army Plaza & Central Park S
# 19310                   Soissons Landing                   Soissons Landing
# ...                                  ...                                ...
# 226                 S 3 St & Bedford Ave               N 6 St & Bedford Ave
# 35811                   12 Ave & W 40 St        Pier 40 - Hudson River Park
# 220                       45 Ave & 21 St                      46 Ave & 5 St
# 4136                    10 Ave & W 14 St                   10 Ave & W 14 St
# 1748              Central Park S & 6 Ave        Central Park West & W 72 St
#
#        start_lat  start_lng    end_lat    end_lng  trips
# 4625   40.765909 -73.976342  40.765909 -73.976342   1001
# 3590   40.766741 -73.979069  40.766741 -73.979069    673
# 4289   40.757284 -73.953600  40.757284 -73.953600    654
# 7081   40.764397 -73.973715  40.764397 -73.973715    614
# 19310  40.692317 -74.014866  40.692317 -74.014866    577
# ...          ...        ...        ...        ...    ...
# 226    40.712605 -73.962644  40.717452 -73.958509    223
# 35811  40.760875 -74.002777  40.727714 -74.011296    220
# 220    40.747371 -73.947773  40.747310 -73.954510    220
# 4136   40.741982 -74.008316  40.741982 -74.008316    218
# 1748   40.765909 -73.976342  40.775794 -73.976206    217
#
# [100 rows x 7 columns]

# %%
df_stations_cleaned = df_stations_cleaned.sort_values(by='trips', ascending=False).head(100000)

# %%
df_stations_cleaned.to_csv(os.path.join(path, 'reduced_data_StationsTrips.csv'))

# %%
df_stations_cleaned.shape
# Out:
# (100000, 7)

# %%
# Create KeplerGl instance

m = KeplerGl(height = 700, data={"data_1": df_stations_cleaned})
m
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_1':                        start_station_name                   end_station_name  \
# 4625 …

# %%
config = m.config

# %%
config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [{'dataId': ['data_1'],
#      'id': '7ndrkomlg',
#      'name': ['trips'],
#      'type': 'range',
#      'value': [60.06, 99],
#      'plotType': 'histogram',
#      'animationWindow': 'free',
#      'yAxis': None,
#      'view': 'side',
#      'speed': 1,
#      'enabled': True}],
#    'layers': [{'id': 'txpux5',
#      'type': 'point',
#      'config': {'dataId': 'data_1',
#       'label': 'start',
#       'color': [69, 138, 70],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'start_lat', 'lng': 'start_lng'},
#       'isVisible': True,
#       'visConfig': {'radius': 10,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'radiusRange': [0, 20],
#        'filled': True},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'strokeColorField': None,
#       'strokeColorScale': 'quantile',
#       'sizeField': {'name': 'trips', 'type': 'integer'},
#       'sizeScale': 'sqrt'}},
#     {'id': 'mqajbms',
#      'type': 'point',
#      'config': {'dataId': 'data_1',
#       'label': 'end',
#       'color': [172, 0, 0],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'end_lat', 'lng': 'end_lng'},
#       'isVisible': True,
#       'visConfig': {'radius': 10,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'radiusRange': [0, 20],
#        'filled': True},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'strokeColorField': None,
#       'strokeColorScale': 'quantile',
#       'sizeField': {'name': 'trips', 'type': 'integer'},
#       'sizeScale': 'sqrt'}},
#     {'id': '89g091n',
#      'type': 'arc',
#      'config': {'dataId': 'data_1',
#       'label': 'start -> end arc',
#       'color': [61, 122, 62],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat0': 'start_lat',
#        'lng0': 'start_lng',
#        'lat1': 'end_lat',
#        'lng1': 'end_lng'},
#       'isVisible': True,
#       'visConfig': {'opacity': 0.8,
#        'thickness': 3,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'sizeRange': [0, 5],
#        'targetColor': [187, 0, 0]},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': {'name': 'trips', 'type': 'integer'},
#       'sizeScale': 'linear'}},
#     {'id': '52ew1in',
#      'type': 'line',
#      'config': {'dataId': 'data_1',
#       'label': 'start -> end line',
#       'color': [241, 92, 23],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat0': 'start_lat',
#        'lng0': 'start_lng',
#        'lat1': 'end_lat',
#        'lng1': 'end_lng'},
#       'isVisible': False,
#       'visConfig': {'opacity': 0.8,
#        'thickness': 2,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'sizeRange': [0, 10],
#        'targetColor': None,
#        'elevationScale': 1},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center',
#         'outlineWidth': 0,
#         'outlineColor': [255, 0, 0, 255],
#         'background': False,
#         'backgroundColor': [0, 0, 200, 255]}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear'}}],
#    'effects': [],
#    'interactionConfig': {'tooltip': {'fieldsToShow': {'data_1': [{'name': 'start_station_name',
#         'format': None},
#        {'name': 'end_station_name', 'format': None},
#        {'name': 'trips', 'format': None}]},
#      'compareMode': False,
#      'compareType': 'absolute',
#      'enabled': True},
#     'brush': {'size': 0.5, 'enabled': False},
#     'geocoder': {'enabled': False},
#     'coordinate': {'enabled': False}},
#    'layerBlending': 'normal',
#    'overlayBlending': 'normal',
#    'splitMaps': [],
#    'animationConfig': {'currentTime': None, 'speed': 1},
#    'editor': {'features': [], 'visible': True}},
#   'mapState': {'bearing': 0,
#    'dragRotate': False,
#    'latitude': 40.73555599439861,
#    'longitude': -74.02300366945241,
#    'pitch': 0,
#    'zoom': 11.096117833833905,
#    'isSplit': False,
#    'isViewportSynced': True,
#    'isZoomLocked': False,
#    'splitMapViewports': []},
#   'mapStyle': {'styleType': 'dark-matter',
#    'topLayerGroups': {},
#    'visibleLayerGroups': {'label': True,
#     'road': True,
#     'border': False,
#     'building': True,
#     'water': True,
#     'land': True,
#     '3d building': False},
#    'threeDBuildingColor': [15.035172933000911,
#     15.035172933000911,
#     15.035172933000911],
#    'backgroundColor': [0, 0, 0],
#    'mapStyles': {}}}}

# %%
import json
with open("config.json", "w") as outfile:
    json.dump(config, outfile)

# %%
m.save_to_html(file_name = 'Bike Trips Aggregated.html', read_only = False, config = config)
# Out:
# Map saved to Bike Trips Aggregated.html!
